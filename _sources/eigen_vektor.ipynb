# %%
import numpy as np
A = [[1, 4],[2, 3]]

mat = np.mat("1 -2;1 3")
#original
print(mat)
print("")

evalue,evektor = np.linalg.eig(A)
print(evalue)
print(np.round(evektor))
# Out:
# [[ 1 -2]
#  [ 1  3]]
#
# [-1.  5.]
# [[-1. -1.]
#  [ 0. -1.]]
